# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
churn = pd.read_csv("churn.csv")
churn
# Out:
#      Customer_ID  Gender  Age  Married  Number_of_Dependents          City  \
# 0     0002-ORFBO  Female   37        1                     0  Frazier Park
# 1     0003-MKNFE    Male   46        0                     0      Glendale
# 2     0004-TLHLJ    Male   50        0                     0    Costa Mesa
# 3     0011-IGKFF    Male   78        1                     0      Martinez
# 4     0013-EXCHZ  Female   75        1                     0     Camarillo
# ...          ...     ...  ...      ...                   ...           ...
# 7038  9987-LUTYD  Female   20        0                     0       La Mesa
# 7039  9992-RRAMN    Male   40        1                     0     Riverbank
# 7040  9992-UJOEL    Male   22        0                     0           Elk
# 7041  9993-LHIEB    Male   21        1                     0  Solana Beach
# 7042  9995-HOTOH    Male   36        1                     0   Sierra City
#
#       Zip_Code   Latitude   Longitude  Number_of_Referrals  ...  \
# ...

# %%
churn.columns.values
# Out:
# array(['Customer_ID', 'Gender', 'Age', 'Married', 'Number_of_Dependents',
#        'City', 'Zip_Code', 'Latitude', 'Longitude', 'Number_of_Referrals',
#        'Tenure_in_Months', 'Offer', 'Phone_Service',
#        'Avg_Monthly_Long_Distance_Charges', 'Multiple_Lines',
#        'Internet_Service', 'Internet_Type', 'Avg_Monthly_GB_Download',
#        'Online_Security', 'Online_Backup', 'Device_Protection_Plan',
#        'Premium_Tech_Support', 'Streaming_TV', 'Streaming_Movies',
#        'Streaming_Music', 'Unlimited_Data', 'Contract',
#        'Paperless_Billing', 'Payment_Method', 'Monthly_Charge',
#        'Total_Charges', 'Total_Refunds', 'Total_Extra_Data_Charges',
#        'Total_Long_Distance_Charges', 'Total_Revenue', 'Customer_Status',
#        'Churn_Category', 'Churn_Reason'], dtype=object)

# %%
churn.describe()
# Out:
#                Age      Married  Number_of_Dependents      Zip_Code  \
# count  7043.000000  7043.000000           7043.000000   7043.000000
# mean     46.509726     0.483033              0.468692  93486.070567
# std      16.750352     0.499748              0.962802   1856.767505
# min      19.000000     0.000000              0.000000  90001.000000
# 25%      32.000000     0.000000              0.000000  92101.000000
# 50%      46.000000     0.000000              0.000000  93518.000000
# 75%      60.000000     1.000000              0.000000  95329.000000
# max      80.000000     1.000000              9.000000  96150.000000
#
#           Latitude    Longitude  Number_of_Referrals  Tenure_in_Months  \
# count  7043.000000  7043.000000          7043.000000       7043.000000
# mean     36.197455  -119.756684             1.951867         32.386767
# std       2.468929     2.154425             3.001199         24.542061
# ...

# %%
churn.dtypes
# Out:
# Customer_ID                           object
# Gender                                object
# Age                                    int64
# Married                                int64
# Number_of_Dependents                   int64
# City                                  object
# Zip_Code                               int64
# Latitude                             float64
# Longitude                            float64
# Number_of_Referrals                    int64
# Tenure_in_Months                       int64
# Offer                                 object
# Phone_Service                          int64
# Avg_Monthly_Long_Distance_Charges    float64
# Multiple_Lines                       float64
# Internet_Service                       int64
# Internet_Type                         object
# Avg_Monthly_GB_Download              float64
# Online_Security                      float64
# Online_Backup                        float64
# Device_Protection_Plan               float64
# ...

# %%
churn.isnull().sum()
# Out:
# Customer_ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number_of_Dependents                    0
# City                                    0
# Zip_Code                                0
# Latitude                                0
# Longitude                               0
# Number_of_Referrals                     0
# Tenure_in_Months                        0
# Offer                                   0
# Phone_Service                           0
# Avg_Monthly_Long_Distance_Charges     682
# Multiple_Lines                        682
# Internet_Service                        0
# Internet_Type                        1526
# Avg_Monthly_GB_Download              1526
# Online_Security                      1526
# Online_Backup                        1526
# Device_Protection_Plan               1526
# Premium_Tech_Support                 1526
# ...

# %%
churn = pd.read_csv("churn.csv")
churn
# Out:
#      Customer_ID  Gender  Age  Married  Number_of_Dependents          City  \
# 0     0002-ORFBO  Female   37        1                     0  Frazier Park
# 1     0003-MKNFE    Male   46        0                     0      Glendale
# 2     0004-TLHLJ    Male   50        0                     0    Costa Mesa
# 3     0011-IGKFF    Male   78        1                     0      Martinez
# 4     0013-EXCHZ  Female   75        1                     0     Camarillo
# ...          ...     ...  ...      ...                   ...           ...
# 7038  9987-LUTYD  Female   20        0                     0       La Mesa
# 7039  9992-RRAMN    Male   40        1                     0     Riverbank
# 7040  9992-UJOEL    Male   22        0                     0           Elk
# 7041  9993-LHIEB    Male   21        1                     0  Solana Beach
# 7042  9995-HOTOH    Male   36        1                     0   Sierra City
#
#       Zip_Code   Latitude   Longitude  Number_of_Referrals  ...  \
# ...

# %%
churn2 = churn.loc[churn['Customer_Status'] != 'Stayed'].copy()
churn2
# Out:
#      Customer_ID  Gender  Age  Married  Number_of_Dependents         City  \
# 2     0004-TLHLJ    Male   50        0                     0   Costa Mesa
# 3     0011-IGKFF    Male   78        1                     0     Martinez
# 4     0013-EXCHZ  Female   75        1                     0    Camarillo
# 17    0021-IKXGC  Female   72        0                     0   San Marcos
# 18    0022-TCJCI    Male   79        0                     0    Daly City
# ...          ...     ...  ...      ...                   ...          ...
# 7033  9975-SKRNR    Male   24        0                     0  Sierraville
# 7036  9985-MWVIX  Female   53        0                     0         Hume
# 7037  9986-BONCE  Female   36        0                     0    Fallbrook
# 7039  9992-RRAMN    Male   40        1                     0    Riverbank
# 7040  9992-UJOEL    Male   22        0                     0          Elk
#
#       Zip_Code   Latitude   Longitude  Number_of_Referrals  ...  \
# ...

# %%
churn
# Out:
#      Customer_ID  Gender  Age  Married  Number_of_Dependents          City  \
# 0     0002-ORFBO  Female   37        1                     0  Frazier Park
# 1     0003-MKNFE    Male   46        0                     0      Glendale
# 2     0004-TLHLJ    Male   50        0                     0    Costa Mesa
# 3     0011-IGKFF    Male   78        1                     0      Martinez
# 4     0013-EXCHZ  Female   75        1                     0     Camarillo
# ...          ...     ...  ...      ...                   ...           ...
# 7038  9987-LUTYD  Female   20        0                     0       La Mesa
# 7039  9992-RRAMN    Male   40        1                     0     Riverbank
# 7040  9992-UJOEL    Male   22        0                     0           Elk
# 7041  9993-LHIEB    Male   21        1                     0  Solana Beach
# 7042  9995-HOTOH    Male   36        1                     0   Sierra City
#
#       Zip_Code   Latitude   Longitude  Number_of_Referrals  ...  \
# ...

# %%
churn_counts = churn2['Customer_Status'].value_counts()
join_counts = churn['Customer_Status'].value_counts()['Joined']
ratio = churn_counts['Churned'] / join_counts

# %%
labels = ['Churned', 'Joined']
values = [churn_counts['Churned'], join_counts]
plt.bar(labels, values)
plt.title('Churned-to-Joined Ratio')
plt.text(0, churn_counts['Churned'], f"{churn_counts['Churned']}")
plt.text(1, join_counts, f"{join_counts}")
plt.text(0.5, max(values)*0.8, f"Ratio: {ratio:.2f}")
plt.show()

# %%
# Data Manipulation: dropping columns that may not be neccesary. Also removed "Joined" in customer_customers as they offer no significant data.
churn = churn.drop(['Customer_ID', 'Latitude', 'Longitude'], axis = 1)
churn.drop(churn[churn['Customer_Status'] == 'Joined'].index, inplace=True)
churn
# Out:
#       Gender  Age  Married  Number_of_Dependents          City  Zip_Code  \
# 0     Female   37        1                     0  Frazier Park     93225
# 1       Male   46        0                     0      Glendale     91206
# 2       Male   50        0                     0    Costa Mesa     92627
# 3       Male   78        1                     0      Martinez     94553
# 4     Female   75        1                     0     Camarillo     93010
# ...      ...  ...      ...                   ...           ...       ...
# 7037  Female   36        0                     0     Fallbrook     92028
# 7038  Female   20        0                     0       La Mesa     91941
# 7039    Male   40        1                     0     Riverbank     95367
# 7041    Male   21        1                     0  Solana Beach     92075
# 7042    Male   36        1                     0   Sierra City     96125
#
#       Number_of_Referrals  Tenure_in_Months    Offer  Phone_Service  ...  \
# ...

# %%
gender = churn['Gender'].value_counts()
gender
# Out:
# Male      3312
# Female    3277
# Name: Gender, dtype: int64

# %%
gender.plot(kind="pie", title='Gender Male/Female', autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Gender Male/Female'}, ylabel='Gender'>

# %%
churn_distribution = churn['Customer_Status'].value_counts()
churn_distribution
# Out:
# Stayed     4720
# Churned    1869
# Name: Customer_Status, dtype: int64

# %%
churn_distribution.plot(kind="pie", title='churn distribution', autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'churn distribution'}, ylabel='Customer_Status'>

# %%
gender_churn = churn.groupby(['Gender', 'Customer_Status']).size().unstack()
gender_churn
# Out:
# Customer_Status  Churned  Stayed
# Gender
# Female               939    2338
# Male                 930    2382

# %%
gender_churn.plot(kind="bar", xlabel='Gender', ylabel='Number of Customer', title='Gender Churn Rate')
# Out:
# <AxesSubplot:title={'center':'Gender Churn Rate'}, xlabel='Gender', ylabel='Number of Customer'>

# %%
churn_category = churn.groupby(["Churn_Category", 'Customer_Status']).size().unstack()
churn_category
# Out:
# Customer_Status  Churned
# Churn_Category
# Attitude             314
# Competitor           841
# Dissatisfaction      321
# Other                182
# Price                211

# %%
churn_category.plot.pie(subplots=True, figsize=(7, 7), autopct='%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='Churned'>], dtype=object)

# %%
churn_reason = churn['Churn_Reason'].value_counts().sort_values(ascending=False)
churn_reason_filtered = churn_reason[churn_reason > 70]
churn_reason_filtered
# Out:
# Competitor had better devices                313
# Competitor made better offer                 311
# Attitude of support person                   220
# Don't know                                   130
# Competitor offered more data                 117
# Competitor offered higher download speeds    100
# Attitude of service provider                  94
# Price too high                                78
# Product dissatisfaction                       77
# Network reliability                           72
# Name: Churn_Reason, dtype: int64

# %%
churn_reason_filtered.plot(kind="bar", xlabel='Reasons', ylabel='Number of Customer', title='Reasons For Churn', figsize=(12, 10))
# Out:
# <AxesSubplot:title={'center':'Reasons For Churn'}, xlabel='Reasons', ylabel='Number of Customer'>

# %%
# Biggest reason for churn was Competitor had better devices. Here, we're using device protection plan as a mesure of good devices.
device_churn = churn.replace({'Device_Protection_Plan': {0.0: 'No', 1.0: 'Yes'}}).groupby(['Device_Protection_Plan', 'Customer_Status']).size().unstack().dropna()
device_churn
# Out:
# Customer_Status         Churned  Stayed
# Device_Protection_Plan
# No                         1211    1644
# Yes                         545    1845

# %%
device_churn.plot(kind="bar", xlabel='Device Protection Plan', ylabel='Number of Customer', title='Churn based on Device Protection Plan')
# Out:
# <AxesSubplot:title={'center':'Churn based on Device Protection Plan'}, xlabel='Device Protection Plan', ylabel='Number of Customer'>

# %%
# Second biggest reason for churn was competitor made better offer. Here we're looking foe the churn rate of different offers.

offer_churn.plot(kind="bar", xlabel='Offer Type', ylabel='Number of Customers', title='Churn to Stay Ratio Based on Offer Types')

# Calculate churned to stayed ratio
offer_churn['Churned to Stayed Ratio'] = offer_churn['Churned'] / offer_churn['Stayed']

# Display churned to stayed ratio on the chart
for i, value in enumerate(offer_churn['Churned to Stayed Ratio']):
    plt.text(i, offer_churn['Churned'][i] + 1, f"{value:.2f}", ha='center')

plt.legend(["Churned", "Stayed"]);
plt.show()

# %%
# Third biggest reason for churn was Attitude of support person. Here we examine the churn rate of customers who has premium customer support. Customers who does not have premium support has a significanlty larger churn rate. It implies customers with premium support enjoys better support experinece. 
support_churn = churn.replace({'Premium_Tech_Support': {0.0: 'No', 1.0: 'Yes'}}).groupby(['Premium_Tech_Support', 'Customer_Status']).size().unstack().dropna()
support_churn
# Out:
# Customer_Status       Churned  Stayed
# Premium_Tech_Support
# No                       1446    1802
# Yes                       310    1687

# %%
support_churn.plot(kind="bar", xlabel='Premium Tech Support', ylabel='Number of Customer', title='Churn Based on Premium Tech Support')
# Out:
# <AxesSubplot:title={'center':'Churn Based on Premium Tech Support'}, xlabel='Premium Tech Support', ylabel='Number of Customer'>

# %%
data_churn = churn.replace({'Unlimited_Data': {0.0: 'No', 1.0: 'Yes'}}).groupby(['Unlimited_Data', 'Customer_Status']).size().unstack().dropna()
data_churn
# Out:
# Customer_Status  Churned  Stayed
# Unlimited_Data
# No                   254     470
# Yes                 1502    3019

# %%
data_churn.plot(kind="bar", xlabel='Unlimited Data', ylabel='Number of Customer', title='Churn Based on Unlimited Data')
# Out:
# <AxesSubplot:title={'center':'Churn Based on Unlimited Data'}, xlabel='Unlimited Data', ylabel='Number of Customer'>

# %%
# Attitude of service provider was the 7th biggest reason for churn. Our chart below shows customers who opt in for phone service also have a higher churn population. There needs to be improvement in the phone service to reduce churn and increase custometr satisfaction.
service_churn['Churned_to_Stayed_Ratio'] = service_churn['Churned'] / service_churn['Stayed']

ax = service_churn[['Churned', 'Stayed']].plot(kind='bar', stacked=True, xlabel='Phone Service', ylabel='Number of Customers', title='Churned to Stayed Ratio for Phone Service')

for i, v in enumerate(service_churn['Churned_to_Stayed_Ratio']):
    ax.text(i, v, f'{v:.2f}', ha='center', va='bottom')

plt.show()

# %%
security_churn = churn.replace({'Online_Security': {0.0: 'No', 1.0: 'Yes'}}).groupby(['Online_Security', 'Customer_Status']).size().unstack().dropna()
security_churn
# Out:
# Customer_Status  Churned  Stayed
# Online_Security
# No                  1461    1811
# Yes                  295    1678

# %%
security_churn.plot(kind="bar", xlabel='Online Security', ylabel='Number of Customer', title='Churn Based on Online Security')
# Out:
# <AxesSubplot:title={'center':'Churn Based on Online Security'}, xlabel='Online Security', ylabel='Number of Customer'>

# %%
city_counts = churn.groupby('City').size()
city_counts_filtered = city_counts[city_counts > 30]
city_counts_filtered.sort_values(ascending=False)
# Out:
# City
# San Diego        278
# Los Angeles      275
# San Jose         110
# Sacramento       102
# San Francisco     97
# Fresno            61
# Long Beach        58
# Escondido         48
# Oakland           47
# Fallbrook         41
# Stockton          41
# Temecula          36
# Bakersfield       35
# Glendale          34
# Berkeley          31
# dtype: int64

# %%
city_churn = churn.groupby(['City', 'Customer_Status']).size().unstack().dropna()
city_result = city_counts_filtered.to_frame().join(city_churn)
city_result.drop(0, axis=1, inplace=True)
city_result = city_result.astype(int)
city_result
# Out:
#                Churned  Stayed
# City
# Bakersfield          2      33
# Berkeley             9      22
# Escondido           16      32
# Fallbrook           26      15
# Fresno              13      48
# Glendale            13      21
# Long Beach          15      43
# Los Angeles         78     197
# Oakland             13      34
# Sacramento          26      76
# San Diego          185      93
# San Francisco       31      66
# San Jose            29      81
# Stockton            12      29
# Temecula            22      14

# %%
# Calculate churned-to-stayed ratio
city_result['Churned_to_Stayed_Ratio'] = city_result['Churned'] / city_result['Stayed']

# Plot the bar graph with churned-to-stayed ratio
ax = city_result[['Churned', 'Stayed']].plot(kind='bar', xlabel='Cities', ylabel='Number of Customers', title='Customer Status Based on City', figsize=(12, 10))

# Add labels to the churned-to-stayed ratio line
for i, v in enumerate(city_result['Churned_to_Stayed_Ratio']):
    ax.text(i, v, f'{v:.2f}', ha='center', va='bottom')

plt.legend(["Churned", "Stayed"])
plt.show()

# %%
churn_reason_san_diego = churn.loc[churn['City'] == 'San Diego'].groupby(['Churn_Reason', 'City']).size().sort_values(ascending=False)
churn_reason_san_diego
# Out:
# Churn_Reason                      City
# Competitor made better offer      San Diego    146
# Don't know                        San Diego     15
# Attitude of support person        San Diego      8
# Competitor had better devices     San Diego      6
# Attitude of service provider      San Diego      2
# Long distance charges             San Diego      2
# Poor expertise of online support  San Diego      2
# Product dissatisfaction           San Diego      2
# Lack of self-service on Website   San Diego      1
# Network reliability               San Diego      1
# dtype: int64

# %%
churn_reason_san_diego.plot(kind="bar", xlabel='Reasons', ylabel='Number of Churned Customer', title='Customer Churn Reason in San Diego', figsize=(8, 6))
plt.legend(["Churned"]);
plt.show()

# %%
offer_san_diego = churn.loc[churn['City'] == 'San Diego'].groupby(['Offer']).size().sort_values(ascending=False)
offer_san_diego
# Out:
# Offer
# None       167
# Offer E     43
# Offer C     24
# Offer D     18
# Offer A     14
# Offer B     12
# dtype: int64

# %%
offer_san_diego.plot(kind="bar", xlabel="Offer type", ylabel='Number of Customer', title='Offers Made To San Diego Customers', figsize=(8, 6))
plt.legend(["Total Offers"]);
plt.show()

# %%
internet_churn['Churned_to_Stayed_Ratio'] = internet_churn['Churned'] / internet_churn['Stayed']
internet_churn
# Out:
# Customer_Status  Churned  Stayed  Churn-to-Stay Ratio  Churned_to_Stayed_Ratio
# Internet_Type
# Cable                213     561             0.379679                 0.379679
# DSL                  307    1230             0.249593                 0.249593
# Fiber Optic         1236    1698             0.727915                 0.727915

# %%
# Plotting the bar chart
ax = internet_churn[['Churned', 'Stayed']].plot(kind='bar', stacked=True, figsize=(10, 6))

# Adding churned-to-stayed ratio as labels
for i, v in enumerate(internet_churn['Churned_to_Stayed_Ratio']):
    ax.text(i, internet_churn['Churned'][i] + internet_churn['Stayed'][i], f"{v:.2f}", ha='center', va='bottom')

# Setting the chart title, x-label, and y-label
ax.set_title("Churned to Stayed Ratio Based on Internet Type")
ax.set_xlabel("Internet Type")
ax.set_ylabel("Number of Customers")

# Displaying the chart
plt.show()

# %%
Contract_churn = churn.groupby(['Contract', 'Customer_Status']).size().unstack()
Contract_churn
# Out:
# Customer_Status  Churned  Stayed
# Contract
# Month-to-Month      1655    1547
# One Year             166    1360
# Two Year              48    1813

# %%
Contract_churn.plot(kind="bar", xlabel='Contract Type', ylabel='Number of Customer', title='Customer Status Based on Contract Type')
# Out:
# <AxesSubplot:title={'center':'Customer Status Based on Contract Type'}, xlabel='Contract Type', ylabel='Number of Customer'>

# %%
payment_churn = churn.groupby(["Payment_Method", 'Customer_Status']).size().unstack()
payment_churn
# Out:
# Customer_Status  Churned  Stayed
# Payment_Method
# Bank Withdrawal     1329    2399
# Credit Card          398    2120
# Mailed Check         142     201

# %%
payment_churn.plot(kind="bar", xlabel='Payment Method', ylabel='Number of Customer', title='Customer Status Based on Payment Method')
# Out:
# <AxesSubplot:title={'center':'Customer Status Based on Payment Method'}, xlabel='Payment Method', ylabel='Number of Customer'>
